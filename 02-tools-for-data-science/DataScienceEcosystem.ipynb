# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## In this notebook, Data Science Tools and Ecosystems are summarized

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#
# 1. Python: General-purpose language for data analysis and machine learning.
# 2. R: Statistical language for data analysis and visualization.
# 3. SQL: Query language for working with databases.

# %% [markdown]
# Some of the commonly used librarys used by Data Scientists include:
#
# 1. Pandas: For data manipulation and analysis
# 2. Numby: For numerical computing and working with arrays.
# 3. Matplotlib: For creating basic plots and visualizations.
# 4. Scikit-learn: For machine learning (classification, regression, clustering).

# %% [markdown]
# |Data Science Tools|
# |------------------|
# |Jupyter Notebook|
# |RStudio |
# |Apache Zeppelin|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in python

# %%
# This is a simple arithmetic expression to multiply then add integers

(3*4) + 5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60

a = int((200/60))

b = float((200/60))

print(a)
print(b)
# Out:
# 3
# 3.3333333333333335

# %% [markdown]
# **Objectives:**
# - List popular languages for Data Science
# - Identify commonly used libraries in Data Science
# - Describe open source tools for Data Science
# - Evaluate arithmetic expressions in Python

# %% [markdown]
# ## Author: Faiyhaa-Sydra Saulat
